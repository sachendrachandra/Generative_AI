# %% [raw]
# The Recursive Character Text Splitter is a text splitter designed to split the text into chunks based on a list of characters provided. It attempts to split text using the characters from a list in order until the resulting chunks are small enough. By default, the list of characters used for splitting is ["\n\n", "\n", " ", "], which tries to keep paragraphs, sentences, and words together as long as possible, as they are generally the most semantically related pieces of text.

# %% [raw]
# To use the RecursiveCharacterTextSplitter, you can create an instance of it and provide the following parameters:
#
# chunk_size : The maximum size of the chunks, as measured by the length_function (default is 100).
#
# chunk_overlap: The maximum overlap between chunks to maintain continuity between them (default is 20).
#
# length_function: parameter is used to calculate the length of the chunks. By default, it is set to len, which counts the number of characters in a chunk. However, you can also pass a token counter or any other function that calculates the length of a chunk based on your specific requirements.

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

loader = PyPDFLoader(r"C:\Users\SACHENDRA\Documents\Activeloop\Langchain_and_Vector_Databases_in_Production\4_Keeping_knowledge_organized_with_indexes\3_What_are_Text_Splitter_and_why_are_they_useful\Sachendra_CV.pdf")

pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=10,
    length_function=len,
)

docs = text_splitter.split_documents(pages)
for doc in docs:
    print(doc)
# Out:
# page_content='Sachendra Chandra' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='♂phone6394633084, 9410411981' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='9410411981 /envel⌢pe07sachendra@gmail.com' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='/linkedinLinkedIn /githubGitHub' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Work Experience' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Data Engineeer 2, Rakuten India August 2021 –' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='2021 – Present' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Mart Migration' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Part of data platform migration project from' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='from Teradata data to Bigquery. Converted the' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='the Systemwalker Jobnet into' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Airflow Python Scripts. These jobnets helped in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='helped in creating the data marts in Teradata. The' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='The corresponding Airflow scripts' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='orchestrated the same data mart creation in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='in BigQuery.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Analyzed the translated Teradata SQL to BigQuery' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='BigQuery SQLs and the data marts created in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='created in BigQuery to ensure exact match' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='between the data of Teradata that with BigQuery' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='BigQuery and automated the validation process for' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='for translated queries on Google' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='BigQuery and Hive and involed in data ingestion' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='ingestion from Teradata to BigQuery via Jenkins.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Part of migration task from C5000 to Minio and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Minio and Bigquery. Translated the Airflow scripts' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='scripts for daily ingestion from Hive to' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Minio and BigQuery.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Skills Used: Python, SQL, Apache Airflow,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Airflow, BigQuery, Teradata, HiveQL' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='POC of Data Mgmt. Tool like Spline and DataHub' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Integrated Spline Data Lineage tool with existing' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='existing code base to track Lineage of Spark job' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Spark job used for mart creation in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='BigQuery and Minio.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Worked on creating a Custom dispatcher using the' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='using the spark spline agent code base so as to' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='so as to extract relevant lineage' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='information for Spark mart creation jobs.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Explored DataHub for capturing, tracking, and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='and visualizing data lineage, allowing' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='allowing organizations to gain valuable insights' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='into their data ecosystems.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Skills Used: Python, Spline, DataHub, Apache' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Apache Spark' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Internal Metadata Management' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Worked on building framework to capture the' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='the dataset and datasource lineage and dataset' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='dataset metadata for spark job used' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='for mart building.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Developed REST Client SDK that leverages Hive' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Hive Metastore service for capturing matadata' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='matadata information of spark job and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='dispatching Metadata and lineage information to' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='to API layer.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Skills Used: Apache Spark, Hive, ArangoDB, Docker' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Operational Artificial General Intelligence (OAGI)' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Thousands of jobs running every day and they' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='and they consume cores, memories, storages and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='and network bandwidth to full-fill' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='their functional goals; those cores, memories,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='memories, storages and network bandwidth are' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='are having the cost based on usage; if' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='those processes are unnecessarily retried and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='and rerun in a circumstance where errors are non' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='are non recoverable, business has to' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='pay unnecessary cost for those resources consumed' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='consumed by processes.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Before retrying, the process asks for the opinion' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='opinion from the OAGI service which is powered by' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='powered by LLM(Large Language' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Model) which has given the enough knowledge of' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='of what kind of exceptions/errors are re-triable' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='re-triable and non re-triable. This' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='saves many resources and directly impacts business' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='business revenue.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Skills Used: Langchain, Llama model, Huggingface' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Education' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Indian Institute of Science, Bangalore Aug. 2019 –' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='2019 – July 2021' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Master of Technology in Computer Science' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Institute of Engineering and Technology, Lucknow' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Lucknow Aug. 2015 – July 2019' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Bachelor of Technology in Information Technology' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='M.Tech. Thesis (GitHub Link)' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Transformer Models for Assertion Generation in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='in JAVA Unit Tests Feb. 2020 – June 2021' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Guide: Prof. Aditya Kanade (SEAL Lab) IISc.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Lab) IISc. Bangalore, Karnataka' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Automatic Assert Statement Generation for Java' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='for Java Unit Test Cases using multiple' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='multiple Transformers Models Fused with Pretrained' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='CuBERT ( CodeUnderstanding BERT ) Encoder - BERT' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='- BERT Large Transformer Encoder by Google.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Fed the JUnit Test methods as input to the CuBERT' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='the CuBERT encoder and used it’s output as' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='output as sentence embeddings for the Junit Test' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='method. Fed this output as input to the modified' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='modified Tranformer models.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='•Used drop-net technique to outperform the' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='the baseline models.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 0}
# page_content='Projects\nAI for Code' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Developed a Langchain application that scrapes' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='scrapes any code repository and uses it’s source' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='source files as a Knowledge document for' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='creating a general purpose application for' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='for developers.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Made use of quantized CodeLama model to leverage' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='leverage the existing code base along with' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='along with Retreival Augmented generation' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='mechanism and Chroma database to generate required' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='required results.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗The developers could ask general questions in' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='in Natural language and even write down unit tests' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='unit tests for the existing source code' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='ML Pipeline for Wine quality application' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Build an Flask web app to detect wine quality' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='quality using ElasticNet Regression along with' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='along with Data Version Control(DVC) framework' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='for tracking versions of models, data and ML' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='and ML pipelines.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗TOX framework was used for creating testing' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='testing modules for the application code. The app' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='The app is deployed on cloud and can be' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='accessed via this link' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Data Pipeline for Kaggle Datasets' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Written spark programs to read the kaggle dataset' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='dataset and saved the data to partitioned parquet' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='parquet format and automated some' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='transformation and analytics spark job using' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='job using airflow and written unit test using' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='test using Funsuite for analytic logic.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Created a new SBT project with all dependencies' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='and builded the jar using SBT assembly.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Data Collection and Modeling NMT model for Source' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='for Source code to Natual Language comments' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Cloned most forked Python Repositories from' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='from GitHub and recursively extracted Python files' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='files from each repository and writing' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Python Script to scrape Functions and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='and corresponding Docstrings form each Python' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Python File.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗2,22,513 (Function, Docstrings) pairs were' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='pairs were extracted for training Machine' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Machine Translation Model to generate Docstrings' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Docstrings for' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='corresponding Python Functions using Transformer' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Encoder-Decoder Architecture with Self-Attention' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='mechanism.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Movie Recommender System' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Involves predicting the unknown ratings(ranging' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='between 0.5-5) given a user-movie pair (Netflix' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='(Netflix Prize Dataset) using concepts' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='of Collaborative Filtering, Non Negative Matrix' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Matrix Factorization(NNMF), Soft Impute etc.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Image Captioning' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗The project involves giving textual caption to an' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='to an image with multi-model and Transfer learning' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='learning technique using both RNN' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='and CNN with pretrained VGG16 model.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗The frontend of the web app is built using Flask' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Flask and backend is created using LSTM python' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='python code and restructuring VGG16' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='pretrained model.The Docker image of the app is' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='the app is deployed on cloud platforms like Heroku' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Heroku or Azure for complete deployment.' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Other Key projects' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗XGBoost Regression, ARIMA Forecasting on COVID19' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='on COVID19 data, Quora Questions Auto-complete' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='suggester, Question Answer' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='retrieval system, Extractive Text Summarization' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Internship' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Cyber Security internship at BSNL ALTTC' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='BSNL ALTTC Ghaziabad, U.P. (Nov. 2017- Dec 2017)' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='∗Performed Case study on Network Security and' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='and Networking by implementing security protocols' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='protocols like TELNET,SSH along with' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='routing configurations and implementing cyber' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='cyber attacks such as SQL injection, Cross-site' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Cross-site scripting, Denial of Service and Buffer' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Overflow attack at RPI Consultants Pvt. Ltd. (Jan' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Ltd. (Jan 2019- Feb 2019)' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Technical Skills\nLanguages : C, Python, Java, SQL' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Libraries : Tensorflow, Pytorch, Keras,Data' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Keras,Data Version control(DVC)' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Technologies/Frameworks : Hadoop, Apache Airflow,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Airflow, BigQuery, Kafka, PySpark, Docker,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='Docker, LangChain' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='ML Algorithms : Decision Tree based models,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='models, Attention Networks, Transformer models,' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
# page_content='models, BERT' metadata={'source': 'C:\\Users\\SACHENDRA\\Documents\\Activeloop\\Langchain_and_Vector_Databases_in_Production\\4_Keeping_knowledge_organized_with_indexes\\3_What_are_Text_Splitter_and_why_are_they_useful\\Sachendra_CV.pdf', 'page': 1}
