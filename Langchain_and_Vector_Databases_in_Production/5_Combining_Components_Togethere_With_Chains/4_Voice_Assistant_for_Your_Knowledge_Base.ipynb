# %%
from dotenv import load_dotenv, dotenv_values
import os

# Load environment variables from .env file
config = dotenv_values("C:/Users/SACHENDRA/Documents/Activeloop/.env")
load_dotenv("C:/Users/SACHENDRA/Documents/Activeloop/.env")
# Out:
# True

# %%
# !pip install elevenlabs==0.2.18
# !pip install streamlit==1.23.1
# !pip install beautifulsoup4==4.11.2
# !pip install audio-recorder-streamlit==0.0.8
# !pip install streamlit-chat==0.0.2.2
# Out:
# Requirement already satisfied: elevenlabs==0.2.18 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (0.2.18)
# Requirement already satisfied: pydantic>=1.10 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from elevenlabs==0.2.18) (1.10.15)
# Requirement already satisfied: ipython>=7.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from elevenlabs==0.2.18) (8.22.2)
# Requirement already satisfied: requests>=2.20 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from elevenlabs==0.2.18) (2.31.0)
# Requirement already satisfied: decorator in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (5.14.3)
# Requirement already satisfied: colorama in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from ipython>=7.0->elevenlabs==0.2.18) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pydantic>=1.10->elevenlabs==0.2.18) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests>=2.20->elevenlabs==0.2.18) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests>=2.20->elevenlabs==0.2.18) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests>=2.20->elevenlabs==0.2.18) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests>=2.20->elevenlabs==0.2.18) (2024.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jedi>=0.16->ipython>=7.0->elevenlabs==0.2.18) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.0->elevenlabs==0.2.18) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from stack-data->ipython>=7.0->elevenlabs==0.2.18) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from stack-data->ipython>=7.0->elevenlabs==0.2.18) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from stack-data->ipython>=7.0->elevenlabs==0.2.18) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=7.0->elevenlabs==0.2.18) (1.16.0)
# Collecting streamlit==1.23.1
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (8.1.7)
# Collecting importlib-metadata<7,>=1.4 (from streamlit==1.23.1)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (1.26.4)
# Collecting packaging<24,>=14.1 (from streamlit==1.23.1)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (2.2.2)
# Collecting pillow<10,>=6.2.0 (from streamlit==1.23.1)
#   Downloading Pillow-9.5.0-cp312-cp312-win_amd64.whl.metadata (9.7 kB)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (4.25.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (16.0.0)
# Collecting pympler<2,>=0.9 (from streamlit==1.23.1)
#   Downloading Pympler-1.0.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (2.9.0)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (8.2.3)
# Requirement already satisfied: toml<2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (4.11.0)
# Collecting tzlocal<5,>=1.1 (from streamlit==1.23.1)
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit==1.23.1)
#   Downloading validators-0.28.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (0.9.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (6.4)
# Requirement already satisfied: watchdog in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit==1.23.1) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit==1.23.1) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit==1.23.1) (4.21.1)
# Requirement already satisfied: toolz in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit==1.23.1) (0.12.1)
# Requirement already satisfied: colorama in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from click<9,>=7.0->streamlit==1.23.1) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit==1.23.1) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit==1.23.1) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit==1.23.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit==1.23.1) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from python-dateutil<3,>=2->streamlit==1.23.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1) (2.17.2)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit==1.23.1)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit==1.23.1) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.23.1) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.23.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.23.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.23.1) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.23.1) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit==1.23.1) (0.1.2)
# Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.9 MB 2.6 MB/s eta 0:00:04
#     --------------------------------------- 0.1/8.9 MB 1.6 MB/s eta 0:00:06
#     --------------------------------------- 0.1/8.9 MB 1.7 MB/s eta 0:00:06
#     --------------------------------------- 0.1/8.9 MB 1.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/8.9 MB 1.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/8.9 MB 1.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/8.9 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/8.9 MB 1.3 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/8.9 MB 1.4 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/8.9 MB 1.4 MB/s eta 0:00:06
1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.5 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.5 MB 1.1 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.5 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.3/2.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.3/2.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.5 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.0 MB/s eta 0:00:00
# Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.8 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.8 kB ? eta -:--:--
#    ------------------- -------------------- 81.9/164.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 143.4/164.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 164.8/164.8 kB 1.2 MB/s eta 0:00:00
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Downloading validators-0.28.1-py3-none-any.whl (39 kB)
# Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: validators, pytz-deprecation-shim, pympler, pillow, packaging, importlib-metadata, tzlocal, streamlit
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.34.0
#     Uninstalling streamlit-1.34.0:
#       Successfully uninstalled streamlit-1.34.0
# Successfully installed importlib-metadata-6.11.0 packaging-23.2 pillow-9.5.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 streamlit-1.23.1 tzlocal-4.3.1 validators-0.28.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\SACHENDRA\miniconda3\envs\activeloop2\Lib\site-packages\~il'.
#   You can safely remove it manually.
# Requirement already satisfied: beautifulsoup4==4.11.2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from beautifulsoup4==4.11.2) (2.5)
# Requirement already satisfied: audio-recorder-streamlit==0.0.8 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (0.0.8)
# Requirement already satisfied: streamlit>=0.63 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from audio-recorder-streamlit==0.0.8) (1.23.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (6.11.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (1.26.4)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (23.2)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.2.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.25.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (16.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.9.0)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (8.2.3)
# Requirement already satisfied: toml<2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.11.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.28.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.9.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (6.4)
# Requirement already satisfied: watchdog in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.21.1)
# Requirement already satisfied: toolz in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.12.1)
# Requirement already satisfied: colorama in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from click<9,>=7.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from python-dateutil<3,>=2->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.17.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from tzlocal<5,>=1.1->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit>=0.63->audio-recorder-streamlit==0.0.8) (0.1.2)
# Requirement already satisfied: streamlit-chat==0.0.2.2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (0.0.2.2)
# Requirement already satisfied: streamlit>=0.63 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit-chat==0.0.2.2) (1.23.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (6.11.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (1.26.4)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (23.2)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (2.2.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (4.25.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (16.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (2.9.0)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (8.2.3)
# Requirement already satisfied: toml<2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (4.11.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (0.28.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (0.9.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (6.4)
# Requirement already satisfied: watchdog in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from streamlit>=0.63->streamlit-chat==0.0.2.2) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (4.21.1)
# Requirement already satisfied: toolz in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.12.1)
# Requirement already satisfied: colorama in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from click<9,>=7.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit>=0.63->streamlit-chat==0.0.2.2) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit>=0.63->streamlit-chat==0.0.2.2) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit>=0.63->streamlit-chat==0.0.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from pandas<3,>=0.25->streamlit>=0.63->streamlit-chat==0.0.2.2) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from python-dateutil<3,>=2->streamlit>=0.63->streamlit-chat==0.0.2.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->streamlit-chat==0.0.2.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->streamlit-chat==0.0.2.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->streamlit-chat==0.0.2.2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from requests<3,>=2.4->streamlit>=0.63->streamlit-chat==0.0.2.2) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from rich<14,>=10.11.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (2.17.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from tzlocal<5,>=1.1->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit>=0.63->streamlit-chat==0.0.2.2) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sachendra\miniconda3\envs\activeloop2\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit>=0.63->streamlit-chat==0.0.2.2) (0.1.2)

# %%
from dotenv import load_dotenv, dotenv_values
import os

# Load environment variables from .env file
config = dotenv_values("C:/Users/SACHENDRA/Documents/Activeloop/.env")
load_dotenv("C:/Users/SACHENDRA/Documents/Activeloop/.env")
# Out:
# True

# %%
import os
import requests
from bs4 import BeautifulSoup
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders import TextLoader
import re

# TODO: use your organization id here. (by default, org id is your username)
my_activeloop_org_id = "sachendra"
my_activeloop_dataset_name = "langchain_course_jarvis_assistant"
dataset_path= f'hub://{my_activeloop_org_id}/{my_activeloop_dataset_name}'

embeddings =  OpenAIEmbeddings(model="text-embedding-ada-002")

# %%
def get_documentation_urls():
    # List of relative URLs for Hugging Face documentation pages, commented a lot of these because it would take too long to scrape all of them
    return [
		    '/docs/huggingface_hub/guides/overview',
		    '/docs/huggingface_hub/guides/download',
		    '/docs/huggingface_hub/guides/upload',
		    '/docs/huggingface_hub/guides/hf_file_system',
		    '/docs/huggingface_hub/guides/repository',
		    '/docs/huggingface_hub/guides/search',
		    # You may add additional URLs here or replace all of them
    ]

def construct_full_url(base_url, relative_url):
    # Construct the full URL by appending the relative URL to the base URL
    return base_url + relative_url

# %%
def scrape_page_content(url):
    # Send a GET request to the URL and parse the HTML response using BeautifulSoup
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    # Extract the desired content from the page (in this case, the body text)
    text=soup.body.text.strip()
    # Remove non-ASCII characters
    text = re.sub(r'[\x00-\x08\x0b-\x0c\x0e-\x1f\x7f-\xff]', '', text)
    # Remove extra whitespace and newlines
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def scrape_all_content(base_url, relative_urls, filename):
    # Loop through the list of URLs, scrape content and add it to the content list
    content = []
    for relative_url in relative_urls:
        full_url = construct_full_url(base_url, relative_url)
        scraped_content = scrape_page_content(full_url)
        content.append(scraped_content.rstrip('\n'))

    # Write the scraped content to a file
    with open(filename, 'w', encoding='utf-8') as file:
        for item in content:
            file.write("%s\n" % item)
    
    return content

# %%
# Define a function to load documents from a file
def load_docs(root_dir,filename):
    # Create an empty list to hold the documents
    docs = []
    try:
        # Load the file using the TextLoader class and UTF-8 encoding
        loader = TextLoader(os.path.join(
            root_dir, filename), encoding='utf-8')
        # Split the loaded file into separate documents and add them to the list of documents
        docs.extend(loader.load_and_split())
    except Exception as e:
        # If an error occurs during loading, ignore it and return an empty list of documents
        pass
    # Return the list of documents
    return docs
  
def split_docs(docs):
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    return text_splitter.split_documents(docs)

# %%
# Define the main function
def main():
    base_url = 'https://huggingface.co'
    # Set the name of the file to which the scraped content will be saved
    filename='content.txt'
    # Set the root directory where the content file will be saved
    root_dir ='./'
    relative_urls = get_documentation_urls()
    # Scrape all the content from the relative URLs and save it to the content file
    content = scrape_all_content(base_url, relative_urls,filename)
    # Load the content from the file
    docs = load_docs(root_dir,filename)
    # Split the content into individual documents
    texts = split_docs(docs)
    # Create a DeepLake database with the given dataset path and embedding function
    db = DeepLake(dataset_path=dataset_path, embedding_function=embeddings)
    # Add the individual documents to the database
    db.add_documents(texts)
    # Clean up by deleting the content file
    os.remove(filename)

# Call the main function if this script is being run as the main program
if __name__ == '__main__':
    main()
# Out:
# |
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/sachendra/langchain_course_jarvis_assistant
# /
# hub://sachendra/langchain_course_jarvis_assistant loaded successfully.
# Deep Lake Dataset in hub://sachendra/langchain_course_jarvis_assistant already exists, loading from the storage
# Dataset(path='hub://sachendra/langchain_course_jarvis_assistant', tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype     shape      dtype  compression
#   -------   -------   -------    -------  -------
#  embedding  generic  (18, 1536)  float32   None
#     ids      text     (18, 1)      str     None
#  metadata    json     (18, 1)      str     None
#    text      text     (18, 1)      str     None
# Evaluating ingest: 100%|█████████████████████████████████████████████████████████████████████████████| 1/1 [00:38<00:00
# /
# Dataset(path='hub://sachendra/langchain_course_jarvis_assistant', tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype     shape      dtype  compression
#   -------   -------   -------    -------  -------
#  embedding  generic  (36, 1536)  float32   None
#     ids      text     (36, 1)      str     None
#  metadata    json     (36, 1)      str     None
#    text      text     (36, 1)      str     None

# %% [markdown]
# Voice Assistant:
#
# Having successfully stored all the necessary data in the vector database, in this instance using Deep Lake by Activeloop, we're ready to utilize this data in our chatbot.
#
# Without further ado, let's transition to the coding part of our chatbot. The following code can be found in the chat.py file of the directory. To give it a try, run streamlit run chat.py.
#
# These libraries will help us in building web applications with Streamlit, handling audio input, generating text responses, and effectively retrieving information stored in the Deep Lake:

# %%
import os
import openai
import streamlit as st
from audio_recorder_streamlit import audio_recorder
from elevenlabs import generate
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake
from streamlit_chat import message

# Constants
TEMP_AUDIO_PATH = "temp_audio.wav"
AUDIO_FORMAT = "audio/wav"

# Load environment variables from .env file and return the keys
openai.api_key = os.environ.get('OPENAI_API_KEY')
eleven_api_key = os.environ.get('ELEVEN_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 4
#       2 import openai
#       3 import streamlit as st
# ----> 4 from audio_recorder_streamlit import audio_recorder
#       5 from elevenlabs import generate
#       6 from langchain.chains import RetrievalQA
#
# File ~\miniconda3\envs\activeloop2\Lib\site-packages\audio_recorder_streamlit\__init__.py:12
#      10     parent_dir = os.path.dirname(os.path.abspath(__file__))
#      11     build_dir = os.path.join(parent_dir, "frontend/build")
# ---> 12     _audio_recorder = components.declare_component(
#      13         "audio_recorder", path=build_dir
#      14     )
#      15 else:
#      16     _audio_recorder = components.declare_component(
#      17         "audio_recorder",
#      18         url="http://localhost:3001",
#      19     )
#
# File ~\miniconda3\envs\activeloop2\Lib\site-packages\streamlit\components\v1\component_registry.py:87, in declare_component(name, path, url)
#      83 # Create our component object, and register it.
#      84 component = CustomComponent(
#      85     name=component_name, path=path, url=url, module_name=module_name
#      86 )
# ---> 87 get_instance().component_registry.register_component(component)
#      89 return component
#
# File ~\miniconda3\envs\activeloop2\Lib\site-packages\streamlit\runtime\__init__.py:28, in get_instance()
#      24 def get_instance() -> Runtime:
#      25     """Return the singleton Runtime instance. Raise an Error if the
#      26     Runtime hasn't been created yet.
#      27     """
# ---> 28     return Runtime.instance()
#
# File ~\miniconda3\envs\activeloop2\Lib\site-packages\streamlit\runtime\runtime.py:163, in Runtime.instance(cls)
#     159 """Return the singleton Runtime instance. Raise an Error if the
#     160 Runtime hasn't been created yet.
#     161 """
#     162 if cls._instance is None:
# --> 163     raise RuntimeError("Runtime hasn't been created!")
#     164 return cls._instance
#
# RuntimeError: Runtime hasn't been created!
